# %% [markdown]
# # Primera entrega ML

# %% [markdown]
# ### Título de proyecto

# %%
# Escribir el título de proyecto en Markdown
titulo = "Predicción de precio del alquiler de viviendas colectivas en España"

# %% [markdown]
# Título = **"Predicción de precio del alquiler de viviendas colectivas en España"**

# %% [markdown]
# ### Tema

# %%
tema = "Se usará el dataset obtenido tras realizar un EDA con el título 'df_alquiler_2020_21_processed'. Este dataset nos permitirá obtener los datos necesarios para obtener un modelo que nos permita predecir el precio medio del alquiler de viviendas colectivas por municipio en España en 2021"  # Breve descripción del proyecto

# %%
# Describir el tema en Markdown

# %% [markdown]
# Se usará el dataset obtenido tras realizar un EDA con el título **'df_alquiler_2020_21_processed.csv'**. Este dataset nos permitirá obtener los datos necesarios para obtener un modelo que nos permita predecir el precio medio del alquiler de viviendas colectivas por municipio en España en 2021.

# %% [markdown]
# ### Datasets y fuentes alternativas de datos
# Incluye aquí una breve descripción del dataset o datasets para tu proyecto. Incluye también las fuentes de cada uno de ellos.

# %%
tipo_ml = "Rergresión" # Regresión? Clasificación?
target_descr = "Precio alquiler colectivo 2021" # Descripción de la variable objetivo
metricas = ['Codigo_provincia', 'Total_vc_2021', 'Total_vu_2021',
       'Alquiler_mes_vc_m2_2021', 'Alquiler_mes_vu_m2_2021',
       'Comunidad_autonoma', 'Poblacion_2021', 'Inmuebles_totales',
       'Viviendas_turisticas_2021', 'Turistas_2021',
       'Porcentaje_viviendas_turisticas_2021', 'Total_casas_alquiler_2021',
       'Porcentaje_viviendas_alquiler_2021', 'Porcentaje_vc_alquiler_2021',
       'Porcentaje_vu_alquiler_2021'] # Metricas escogidas para evaluar los modelos

# %%
import pandas as pd

# dasets y enlaces de datasets en Markdown
df_1 = pd.read_csv("data/raw/df_alquiler_2020_21_processed.csv", sep=";", index_col=0) # ["www.paginacondatos.com", "www.paginawebscrapeada.com", "www.unaapi.com"]

# %%
# load dataset
df_1.head()
# Out:
#           Codigo_provincia  Provincia  Codigo_municipio  Total_vc_2020
# Abadín                  27       Lugo             27001     204.615385  \
# Abanilla                30     Murcia             30001      15.000000
# Abarán                  30     Murcia             30002     188.000000
# Abegondo                15  Coruña, A             15001       7.000000
# Abrera                   8  Barcelona              8001     374.000000
#
#           Total_vu_2020  Alquiler_mes_vc_m2_2020  Alquiler_mes_vu_m2_2020
# Abadín             11.0                 2.793878                 1.346634  \
# Abanilla           22.0                 3.036911                 1.546392
# Abarán             54.0                 2.961165                 2.727273
# Abegondo           60.0                 3.585766                 3.200000
# Abrera            153.0                 6.782946                 6.734083
#
#           Total_vc_2021  Total_vu_2021  Alquiler_mes_vc_m2_2021  ...
# ...
